# %% [markdown]
# # Tarea Semanal 9 - Funciones de excitación no disipativas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cálculos

# %%
from IPython.display import IFrame

IFrame(src='TS9.pdf', width=900, height=1200)
# Out:
#         <iframe
#             width="900"
#             height="1200"
#             src="TS9.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Simulaciones

# %% [markdown]
# ### Ejercicio 1
#
# #### Método Foster Paralelo
#
# ![image-2.png](attachment:image-2.png)
#
#
# #### Método Cawer 1:
#
# ![image-3.png](attachment:image-3.png)
#
#
# #### Método Cawer 2:
# ![image-4.png](attachment:image-4.png)
#
# Vemos que todas las gráficas son exactamente iguales, dado que justamente tienen la misma función admitancia y cumplen con la transferencia:
#
# * Ceros en el origen y en el infinito
# * Un cero de transmisión en F = 244.94mHz, es decir, W = sqrt(2) rad/seg
# * Un polo en F = 159.11mHz, es decir, W = 1 rad/seg
# * Un polo en F = 275.48mHz, es decir, W = sqrt(3) rad/seg

# %% [markdown]
# ### Ejercicio 2
# #### Verificacion Transferencia
# ![image-2.png](attachment:image-2.png)
#
# Vemos que cumplen con la transferencia:
#
# * Ceros en el origen y en el infinito
# * Un cero de transmisión en F = 243.29mHz, es decir, W = sqrt(7/3)rad/seg
# * Un polo en F = 224.63mHz, es decir, W = sqrt(2) rad/seg
# * Un polo en F = 356.43mHz, es decir, W = sqrt(5) rad/seg
#
# #### Verificacion resonancia de L1 C1
# ![image.png](attachment:image.png)
#
# Vemos que resuena a F = 159mHz, es decir, 1 rad/seg
