# %% [markdown]
# <H1><u>Tarea semanal 12</u></H1>

# %% [markdown]
# <H2><center><u>Consignas</u></center></H2>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Cálculos

# %%
from IPython.display import IFrame
IFrame(src='TS12.pdf', width=900, height=1200)
# Out:
#         <iframe
#             width="900"
#             height="1200"
#             src="TS12.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
