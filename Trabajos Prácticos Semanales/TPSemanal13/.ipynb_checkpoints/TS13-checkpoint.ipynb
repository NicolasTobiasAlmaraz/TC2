# %% [markdown]
# <H1><u>Tarea semanal 13</u></H1>

# %% [markdown]
# <H2><center><u>Consignas</u></center></H2>

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Cálculos

# %%
from IPython.display import IFrame
IFrame(src='TS13.pdf', width=900, height=1200)
# Out:
#         <iframe
#             width="900"
#             height="1200"
#             src="TS13.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
